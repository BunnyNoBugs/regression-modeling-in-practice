# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
gm = pd.read_csv('gapminder.csv', na_values=' ', index_col=0)
gm
# Out:
#                     incomeperperson  alcconsumption  armedforcesrate  \
# country
# Afghanistan                     NaN            0.03         0.569653
# Albania                 1914.996551            7.29         1.024736
# Algeria                 2231.993335            0.69         2.306817
# Andorra                21943.339898           10.17              NaN
# Angola                  1381.004268            5.57         1.461329
# ...                             ...             ...              ...
# Vietnam                  722.807559            3.91         1.085367
# West Bank and Gaza              NaN             NaN         5.936085
# Yemen, Rep.              610.357367            0.20         2.316235
# Zambia                   432.226337            3.56         0.341335
# Zimbabwe                 320.771890            4.96         1.032785
#
#                     breastcancerper100th  co2emissions  femaleemployrate  \
# country
# Afghanistan                         26.8  7.594400e+07         25.600000
# Albania                             57.4  2.237473e+08         42.099998
# Algeria                             23.5  2.932109e+09         31.700001
# Andorra                              NaN           NaN               NaN
# Angola                              23.1  2.483580e+08         69.400002
# ...                                  ...           ...               ...
# Vietnam                             16.2  1.425435e+09         67.599998
# West Bank and Gaza                   NaN  1.424133e+07         11.300000
# Yemen, Rep.                         35.1  2.348647e+08         20.299999
# Zambia                              13.0  1.320257e+08         53.500000
# Zimbabwe                            19.0  5.902197e+08         58.099998
#
#                     hivrate  internetuserate  lifeexpectancy  oilperperson  \
# country
# Afghanistan             NaN         3.654122          48.673           NaN
# Albania                 NaN        44.989947          76.918           NaN
# Algeria                 0.1        12.500073          73.131      0.420095
# Andorra                 NaN        81.000000             NaN           NaN
# Angola                  2.0         9.999954          51.093           NaN
# ...                     ...              ...             ...           ...
# Vietnam                 0.4        27.851822          75.181           NaN
# West Bank and Gaza      NaN        36.422772          72.832           NaN
# Yemen, Rep.             NaN        12.349750          65.493           NaN
# Zambia                 13.5        10.124986          49.025           NaN
# Zimbabwe               14.3        11.500415          51.384           NaN
#
#                     polityscore  relectricperperson  suicideper100th  \
# country
# Afghanistan                 0.0                 NaN         6.684385
# Albania                     9.0          636.341383         7.699330
# Algeria                     2.0          590.509814         4.848770
# Andorra                     NaN                 NaN         5.362179
# Angola                     -2.0          172.999227        14.554677
# ...                         ...                 ...              ...
# Vietnam                    -7.0          302.725655        11.653322
# West Bank and Gaza          NaN                 NaN              NaN
# Yemen, Rep.                -2.0          130.057831         6.265789
# Zambia                      7.0          168.623031        12.019036
# Zimbabwe                    1.0          297.883200        13.905267
#
#                     employrate  urbanrate
# country
# Afghanistan          55.700001      24.04
# Albania              51.400002      46.72
# Algeria              50.500000      65.22
# Andorra                    NaN      88.92
# Angola               75.699997      56.70
# ...                        ...        ...
# Vietnam              71.000000      27.84
# West Bank and Gaza   32.000000      71.90
# Yemen, Rep.          39.000000      30.64
# Zambia               61.000000      35.42
# Zimbabwe             66.800003      37.34
#
# [213 rows x 15 columns]

# %%
gm.mean()
# Out:
# incomeperperson         8.740966e+03
# alcconsumption          6.689412e+00
# armedforcesrate         1.444016e+00
# breastcancerper100th    3.740289e+01
# co2emissions            5.033262e+09
# femaleemployrate        4.754944e+01
# hivrate                 1.935442e+00
# internetuserate         3.563272e+01
# lifeexpectancy          6.975352e+01
# oilperperson            1.484085e+00
# polityscore             3.689441e+00
# relectricperperson      1.173179e+03
# suicideper100th         9.640839e+00
# employrate              5.863596e+01
# urbanrate               5.676936e+01
# dtype: float64

# %%
for i in gm:
    if i != 'polityscore':
        gm[i] -= gm[i].mean()

# %%
gm.mean()
# Out:
# incomeperperson        -2.872089e-14
# alcconsumption         -6.886945e-17
# armedforcesrate        -7.040439e-17
# breastcancerper100th   -5.750057e-16
# co2emissions           -9.870529e-07
# femaleemployrate        5.808088e-15
# hivrate                -1.450087e-16
# internetuserate        -3.071617e-15
# lifeexpectancy          8.072658e-15
# oilperperson           -8.811294e-17
# polityscore             3.689441e+00
# relectricperperson     -4.179663e-14
# suicideper100th        -6.231199e-16
# employrate             -2.674515e-15
# urbanrate              -3.080185e-15
# dtype: float64

# %%
f = plt.figure(figsize=(10, 10))
plt.matshow(gm.corr(), fignum=f.number, cmap='bwr')
plt.xticks(range(gm.select_dtypes(['number']).shape[1]), gm.select_dtypes(['number']).columns, fontsize=14, rotation=90)
plt.yticks(range(gm.select_dtypes(['number']).shape[1]), gm.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
for i in gm:
    if i != 'polityscore':
        plt.figure()
        sns.regplot(x=i, y='polityscore', data=gm)

# %%
reg = smf.ols('polityscore ~ armedforcesrate + breastcancerper100th + alcconsumption', data=gm).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            polityscore   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     31.14
# Date:                Mon, 29 Mar 2021   Prob (F-statistic):           1.22e-15
# Time:                        02:50:15   Log-Likelihood:                -453.86
# No. Observations:                 151   AIC:                             915.7
# Df Residuals:                     147   BIC:                             927.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                3.6665      0.404      9.080      0.000       2.869       4.465
# armedforcesrate         -1.1208      0.271     -4.133      0.000      -1.657      -0.585
# breastcancerper100th     0.1173      0.021      5.694      0.000       0.077       0.158
# alcconsumption           0.2344      0.093      2.516      0.013       0.050       0.418
# ==============================================================================
# Omnibus:                        9.052   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                8.049
# Skew:                          -0.490   Prob(JB):                       0.0179
# Kurtosis:                       2.436   Cond. No.                         22.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Q-Q plot for normality
fig = sm.qqplot(reg.resid, line='r')

# %%
# simple plot of residuals
stdres = pd.DataFrame(reg.resid_pearson)
plt.plot(stdres, 'o', ls='None')
l = plt.axhline(y=0, color='r')
plt.ylabel('Standardized Residual')
plt.xlabel('Observation Number');

# %%
# additional regression diagnostic plots
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(reg,  'alcconsumption', fig=fig)

# %%
# leverage plot
fig = sm.graphics.influence_plot(reg, size=9)

# %%
sns.regplot(x='urbanrate', y='polityscore', data=gm);
